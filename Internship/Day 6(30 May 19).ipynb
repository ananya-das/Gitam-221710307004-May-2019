# %% [markdown]
# # Problem solving and Programming
# ## Day No : 6
# ## Date      : 30-May-2019

# %% [markdown]
# # USING OOP CONCEPT

# %% [markdown]
# # Problem1:
# Draw a pie plot based on number of wins for each team

# %%
class win_pieplot():
    def __init__(self, filename):
        self.df = pd.read_csv(filename)
        self.won=[]
        self.team,self.unique_team=[],[]
        #self.unique_won,self.freq=[],[]
        self.toss=[]
        self.matwin = []
        
    def win_data(self):
        self.team.append(self.df['Team1'].values)
        
        
        for i in range(0,len(self.team[0])):            
            self.toss.append(self.df.iat[i,9])
                
        
        for i in range(0,len(self.team[0])):
            self.matwin.append(self.df.iat[i,10])
            
        
        for i in range(0,len(self.toss)):
            if(self.df.iat[i,9]==self.df.iat[i,10]):
                self.won.append(self.df.iat[i,10])
                
        
        self.unique_won,self.freq = list(np.unique(self.won, return_counts=True))
        
        
        labels = self.unique_won
        number_of_win = self.freq

        fig1, ax1 = plt.subplots()
        ax1.pie(number_of_win, labels=labels, autopct='%1.2f%%',
                shadow=True, startangle=90, radius = 1.8 * 10000)

        ax1.axis('equal') 
        plt.show()     
        
        
final = win_pieplot('Match1.csv')
final.win_data()
# Out:
# ['Chennai Super Kings' 'Deccan Chargers' 'Delhi Daredevils'
#  'Gujarat Lions' 'Kings XI Punjab' 'Kochi Tuskers Kerala'
#  'Kolkata Knight Riders' 'Mumbai Indians' 'Pune Warriors'
#  'Rajasthan Royals' 'Rising Pune Supergiants'
#  'Royal Challengers Bangalore' 'Sunrisers Hyderabad']

# %% [markdown]
# # Problem2:
# Draw a bar graph for number of matches won (i,e.consider win if the team wins both the toss and match)  for the team “Mumbai Indians” for all years

# %%
class win_pieplot():
    def __init__(self, filename):
        self.df = pd.read_csv(filename)
        self.won=[]
        self.team=[]
        self.toss=[]
        self.matwin = []
        self.t_2008,self.t_2009,self.t_2010,self.t_2011,self.t_2012,self.t_2013,self.t_2014,self.t_2015,self.t_2016,self.t_2017=[],[],[],[],[],[],[],[],[],[]
        self.u_2008,self.u_2009,self.u_2010,self.u_2011,self.u_2012,self.u_2013,self.u_2014,self.u_2015,self.u_2016,self.u_2017=[],[],[],[],[],[],[],[],[],[]
        self.r=[]
        
    def win_data(self):
        self.team.append(self.df['Team1'].values)
        
        
        
                
        #print(self.won)
        
        for i in range(0,len(self.team[0])):
            if(self.df.iat[i,5]==2008):
                self.t_2008.append(self.df.iat[i,10])
                
            elif(self.df.iat[i,5]==2009):
                self.t_2009.append(self.df.iat[i,10])
                
            elif(self.df.iat[i,5]==2010):
                self.t_2010.append(self.df.iat[i,10])
                
            elif(self.df.iat[i,5]==2011):
                self.t_2011.append(self.df.iat[i,10])
                
            elif(self.df.iat[i,5]==2012):
                self.t_2012.append(self.df.iat[i,10])
                
            elif(self.df.iat[i,5]==2013):
                self.t_2013.append(self.df.iat[i,10])
                
            elif(self.df.iat[i,5]==2014):
                self.t_2014.append(self.df.iat[i,10])
                
            elif(self.df.iat[i,5]==2015):
                self.t_2015.append(self.df.iat[i,10])
                
            elif(self.df.iat[i,5]==2016):
                self.t_2016.append(self.df.iat[i,10])
                
            elif(self.df.iat[i,5]==2017):
                self.t_2017.append(self.df.iat[i,10])
                
        for i in range(0,len(self.t_2008)):
            if(self.df.iat[i,9]==self.df.iat[i,10]):
                self.u_2008.append(self.df.iat[i,10])
                
        length = len(self.t_2008)
                
        for i in range(length,length+len(self.t_2009)):
            if(self.df.iat[i,9]==self.df.iat[i,10]):
                self.u_2009.append(self.df.iat[i,10])
                
        length = length+len(self.t_2009)
        
        for i in range(length,length+len(self.t_2010)):
            if(self.df.iat[i,9]==self.df.iat[i,10]):
                self.u_2010.append(self.df.iat[i,10])
                
        length = length+len(self.t_2010)
        
        for i in range(length,length+len(self.t_2011)):
            if(self.df.iat[i,9]==self.df.iat[i,10]):
                self.u_2011.append(self.df.iat[i,10])
        
        length = length+len(self.t_2011)
        
        for i in range(length,length+len(self.t_2012)):
            if(self.df.iat[i,9]==self.df.iat[i,10]):
                self.u_2012.append(self.df.iat[i,10])
                
        length = length+len(self.t_2012)
        
        for i in range(length,length+len(self.t_2013)):
            if(self.df.iat[i,9]==self.df.iat[i,10]):
                self.u_2013.append(self.df.iat[i,10])    
                
        length = length+len(self.t_2013)
        
        for i in range(length,length+len(self.t_2014)):
            if(self.df.iat[i,9]==self.df.iat[i,10]):
                self.u_2014.append(self.df.iat[i,10])    
                
        length = length+len(self.t_2014)
        
        for i in range(length,length+len(self.t_2015)):
            if(self.df.iat[i,9]==self.df.iat[i,10]):
                self.u_2015.append(self.df.iat[i,10])  
                
        length = length+len(self.t_2015)
        
        for i in range(length,length+len(self.t_2016)):
            if(self.df.iat[i,9]==self.df.iat[i,10]):
                self.u_2016.append(self.df.iat[i,10])   
                
        length = length+len(self.t_2016)
        
        for i in range(length,length+len(self.t_2017)):
            if(self.df.iat[i,9]==self.df.iat[i,10]):
                self.u_2017.append(self.df.iat[i,10])    
                
                
        y2008 = 0
        for i in range(0,len(self.u_2008)):
            if(self.u_2008[i] == 'Mumbai Indians'):
                y2008+=1
        self.r.append(y2008)
        
        y2009 = 0
        for i in range(0,len(self.u_2009)):
            if(self.u_2009[i] == 'Mumbai Indians'):
                y2009+=1
        self.r.append(y2009)
        
        y2010 = 0
        for i in range(0,len(self.u_2010)):
            if(self.u_2010[i] == 'Mumbai Indians'):
                y2010+=1
        self.r.append(y2010)
        
        y2011 = 0
        for i in range(0,len(self.u_2011)):
            if(self.u_2011[i] == 'Mumbai Indians'):
                y2011+=1
        self.r.append(y2011)
        
        y2012 = 0
        for i in range(0,len(self.u_2012)):
            if(self.u_2012[i] == 'Mumbai Indians'):
                y2012+=1
        self.r.append(y2012)
        
        y2013 = 0
        for i in range(0,len(self.u_2013)):
            if(self.u_2013[i] == 'Mumbai Indians'):
                y2013+=1
        self.r.append(y2013)
        
        y2014 = 0
        for i in range(0,len(self.u_2014)):
            if(self.u_2014[i] == 'Mumbai Indians'):
                y2014+=1
        self.r.append(y2014)
        
        
        y2015 = 0
        for i in range(0,len(self.u_2015)):
            if(self.u_2015[i] == 'Mumbai Indians'):
                y2015+=1
        self.r.append(y2015)
        
        y2016 = 0
        for i in range(0,len(self.u_2016)):
            if(self.u_2016[i] == 'Mumbai Indians'):
                y2016+=1
        self.r.append(y2016)
        
        y2017 = 0
        for i in range(0,len(self.u_2017)):
            if(self.u_2017[i] == 'Mumbai Indians'):
                y2017+=1
        self.r.append(y2017)
        
        
        
        print(self.r)
        years=[2008,2009,2010,2011,2012,2013,2014,2015,2016,2017]
        width = 0.5
        plt.bar(years,self.r,width,color = 'Purple')
        
final = win_pieplot('Match1.csv')
final.win_data()
# Out:
# [4, 3, 6, 3, 6, 8, 3, 3, 5, 7]
