# %% [markdown]
# # Day - 7
# # Date - 31 May 2019
# # Outcomes -
# >* To analyse cricket data sets using Object Oriented Approach

# %% [markdown]
# ##

# %% [markdown]
# ## Task 1 : How many runs of  Dhoni On 4/23/2008  Chennai Super Kings vs Mumbai Indians Match

# %%
import pandas as pd
import numpy as np

class dhoniRuns():
    def __init__(self, ballData):
        #reading the file
        self.df = pd.read_csv(ballData)
        
    def generateDhoniRuns(self):
        # collecting the data for ms.dhoni
        no_runs = [(self.df.iat[i,8]) for i in range(0, len(self.df)) if self.df.iat[i,0] == 335994 if self.df.iat[i,34] == 12862]
        
        for i in range(0, len(self.df)):
            if self.df.iat[i,0] == 335994:
                if self.df.iat[i,34] == 12862:
                    no_runs.append(self.df.iat[i,9])
                    
        print('Total number of runs of MS.Dhoni on 4/23/2008 during "Chennai Super Kings vs Mumbai Indians" Match : ', sum(no_runs))
        return

runs = dhoniRuns('Ball_By_Ball.csv')
runs.generateDhoniRuns()
# Out:
# Total number of runs of MS.Dhoni on 4/23/2008 during "Chennai Super Kings vs Mumbai Indians" Match :  32

# %% [markdown]
# ##

# %% [markdown]
# ## Task 2 : From 4/23/2008  Chennai Super Kings vs Mumbai Indians Match:
#     Plot a bar graph for all the players in the 'Mumbai Indians' team

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

class MumbaiIndians():
    def __init__(self, ballData,f2):
        # reading the file
        self.df = pd.read_csv(ballData)
        self.df2 = pd.read_csv(f2)
        self.r=[]
        
    def generateBarGraph(self):
        players = [self.df.iat[i,4] for i in range(0, len(self.df)) if self.df.iat[i,2] == 335994 if self.df.iat[i,10] == 'Mumbai Indians']
        
        # collecting the data for mumbai indians team
        
        player_id= [self.df.iat[i,0] for i in range(0,len(self.df)) if self.df.iat[i,2]== 335994 if self.df.iat[i,10] == 'Mumbai Indians']
        print(player_id)
        
        
        
        

        no_runs1 = [(self.df2.iat[i,8]) for i in range(0, len(self.df2)) if self.df2.iat[i,0] == 335994 if self.df2.iat[i,34] == 12848]
        self.r.append(sum(no_runs1))
        no_runs2 = [(self.df2.iat[i,8]) for i in range(0, len(self.df2)) if self.df2.iat[i,0] == 335994 if self.df2.iat[i,34] == 12849]
        self.r.append(sum(no_runs2))
        no_runs3 = [(self.df2.iat[i,8]) for i in range(0, len(self.df2)) if self.df2.iat[i,0] == 335994 if self.df2.iat[i,34] == 12850]
        self.r.append(sum(no_runs3))
        no_runs4 = [(self.df2.iat[i,8]) for i in range(0, len(self.df2)) if self.df2.iat[i,0] == 335994 if self.df2.iat[i,34] == 12851]
        self.r.append(sum(no_runs4))
        no_runs5 = [(self.df2.iat[i,8]) for i in range(0, len(self.df2)) if self.df2.iat[i,0] == 335994 if self.df2.iat[i,34] == 12852]
        self.r.append(sum(no_runs5))
        no_runs6 = [(self.df2.iat[i,8]) for i in range(0, len(self.df2)) if self.df2.iat[i,0] == 335994 if self.df2.iat[i,34] == 12853]
        self.r.append(sum(no_runs6))
        no_runs7 = [(self.df2.iat[i,8]) for i in range(0, len(self.df2)) if self.df2.iat[i,0] == 335994 if self.df2.iat[i,34] == 12854]
        self.r.append(sum(no_runs7))
        no_runs8 = [(self.df2.iat[i,8]) for i in range(0, len(self.df2)) if self.df2.iat[i,0] == 335994 if self.df2.iat[i,34] == 12855]
        self.r.append(sum(no_runs8))
        no_runs9 = [(self.df2.iat[i,8]) for i in range(0, len(self.df2)) if self.df2.iat[i,0] == 335994 if self.df2.iat[i,34] == 12856]
        self.r.append(sum(no_runs9))
        no_runs10 = [(self.df2.iat[i,8]) for i in range(0, len(self.df2)) if self.df2.iat[i,0] == 335994 if self.df2.iat[i,34] == 12857]
        self.r.append(sum(no_runs10))
        no_runs11 = [(self.df2.iat[i,8]) for i in range(0, len(self.df2)) if self.df2.iat[i,0] == 335994 if self.df2.iat[i,34] == 12858]
        self.r.append(sum(no_runs11))
        
        print(self.r)
        

        
        # generating bar graph with the collected data
        width = 1/2
        plt.title("Mumbai Indians' Team")
        plt.bar(players,self.r, width, color = 'pink')
        plt.xticks(players,fontsize = 9, rotation = 30)
        return

runs = MumbaiIndians('Player_match.csv','Ball_By_Ball.csv')
runs.generateBarGraph()
# Out:
# [12848, 12849, 12850, 12851, 12852, 12853, 12854, 12855, 12856, 12857, 12858]
# [2, 20, 43, 45, 17, 28, 24, 9, 1, 0, 0]
