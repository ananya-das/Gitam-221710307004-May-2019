# %% [markdown]
# # Problem Solving and Programming

# %% [markdown]
# ## Day No.-  05

# %% [markdown]
# ## Date: 08 May 19

# %% [markdown]
# ### Day objective
# * Objective 1
# * Objective 2
# * Objective 3

# %% [markdown]
# ### problem1:
# #### problem statement:
#
# #### Constraints:
#
# #### Test Case
# * Test case 1
# * Test case 2
# * Test case 3
